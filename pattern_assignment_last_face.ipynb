# %%
import numpy as np
from sklearn.datasets import fetch_lfw_people
from sklearn.decomposition import PCA, KernelPCA
from sklearn.manifold import MDS, LocallyLinearEmbedding, Isomap
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
# 加载 LFW 数据集
lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

# 提取面部图像的特征向量和标签
X = lfw_people.data
y = lfw_people.target
target_names = lfw_people.target_names

# %%
def reduce_dimensions(method, data):
    if method == 'PCA':
        model = PCA(n_components=100)
    elif method == 'KPCA':
        model = KernelPCA(n_components=100, kernel='rbf')
    elif method == 'MDS':
        model = MDS(n_components=2)
    elif method == 'LLE':
        model = LocallyLinearEmbedding(n_components=2)
    elif method == 'ISOMAP':
        model = Isomap(n_components=2)
    else:
        raise ValueError('Invalid dimensionality reduction method')
    return model.fit_transform(data)

def feature_selection(data, labels, num_features=50):
    # 确保不选择超过现有特征数的特征
    num_features = min(num_features, data.shape[1])
    selector = SelectKBest(f_classif, k=num_features)
    return selector.fit_transform(data, labels)


def classify_and_evaluate(classifier, train_data, train_labels, test_data, test_labels):
    classifier.fit(train_data, train_labels)
    predictions = classifier.predict(test_data)
    return classification_report(test_labels, predictions, target_names=target_names)

# %%
methods = ['PCA', 'KPCA', 'MDS', 'LLE', 'ISOMAP']
classifiers = [SVC(), GaussianNB(), DecisionTreeClassifier()]
results = {}

for method in methods:
    reduced_data = reduce_dimensions(method, X)
    selected_data = feature_selection(reduced_data, y)
    
    X_train, X_test, y_train, y_test = train_test_split(selected_data, y, test_size=0.2)
    
    for classifier in classifiers:
        key = f'{method}_{type(classifier).__name__}'
        report = classify_and_evaluate(classifier, X_train, y_train, X_test, y_test)
        results[key] = report

# 打印结果
for key, report in results.items():
    print(f'{key}:\n{report}\n')
# Out:
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# PCA_SVC:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.86      0.40      0.55        15
#      Colin Powell       0.67      0.90      0.77        39
#   Donald Rumsfeld       0.89      0.65      0.76        26
#     George W Bush       0.84      0.97      0.90       112
# Gerhard Schroeder       0.71      0.50      0.59        24
#       Hugo Chavez       0.89      0.73      0.80        11
#        Tony Blair       0.83      0.65      0.73        31
#
#          accuracy                           0.80       258
#         macro avg       0.81      0.69      0.73       258
#      weighted avg       0.81      0.80      0.79       258
#
#
# PCA_GaussianNB:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.77      0.67      0.71        15
#      Colin Powell       0.70      0.85      0.77        39
#   Donald Rumsfeld       0.80      0.62      0.70        26
#     George W Bush       0.78      0.91      0.84       112
# Gerhard Schroeder       0.77      0.42      0.54        24
#       Hugo Chavez       0.89      0.73      0.80        11
#        Tony Blair       0.88      0.71      0.79        31
#
#          accuracy                           0.78       258
#         macro avg       0.80      0.70      0.73       258
#      weighted avg       0.78      0.78      0.77       258
#
#
# PCA_DecisionTreeClassifier:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.10      0.07      0.08        15
#      Colin Powell       0.33      0.44      0.38        39
#   Donald Rumsfeld       0.25      0.23      0.24        26
#     George W Bush       0.66      0.69      0.67       112
# Gerhard Schroeder       0.25      0.21      0.23        24
#       Hugo Chavez       0.17      0.18      0.17        11
#        Tony Blair       0.33      0.26      0.29        31
#
#          accuracy                           0.45       258
#         macro avg       0.30      0.30      0.29       258
#      weighted avg       0.44      0.45      0.44       258
#
#
# KPCA_SVC:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.88      0.44      0.58        16
#      Colin Powell       0.83      0.88      0.85        43
#   Donald Rumsfeld       0.86      0.64      0.73        28
#     George W Bush       0.80      0.96      0.87       114
# Gerhard Schroeder       0.63      0.55      0.59        22
#       Hugo Chavez       0.80      0.33      0.47        12
#        Tony Blair       0.76      0.70      0.73        23
#
#          accuracy                           0.79       258
#         macro avg       0.79      0.64      0.69       258
#      weighted avg       0.80      0.79      0.78       258
#
#
# KPCA_GaussianNB:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.80      0.50      0.62        16
#      Colin Powell       0.80      0.84      0.82        43
#   Donald Rumsfeld       0.92      0.79      0.85        28
#     George W Bush       0.78      0.90      0.84       114
# Gerhard Schroeder       0.65      0.59      0.62        22
#       Hugo Chavez       0.67      0.33      0.44        12
#        Tony Blair       0.62      0.57      0.59        23
#
#          accuracy                           0.77       258
#         macro avg       0.75      0.65      0.68       258
#      weighted avg       0.77      0.77      0.76       258
#
#
# KPCA_DecisionTreeClassifier:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.06      0.06      0.06        16
#      Colin Powell       0.45      0.44      0.45        43
#   Donald Rumsfeld       0.38      0.36      0.37        28
#     George W Bush       0.62      0.54      0.57       114
# Gerhard Schroeder       0.15      0.18      0.16        22
#       Hugo Chavez       0.12      0.17      0.14        12
#        Tony Blair       0.23      0.30      0.26        23
#
#          accuracy                           0.40       258
#         macro avg       0.29      0.29      0.29       258
#      weighted avg       0.43      0.40      0.42       258
#
#
# MDS_SVC:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        17
#      Colin Powell       0.00      0.00      0.00        48
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.40      1.00      0.57       102
# Gerhard Schroeder       0.00      0.00      0.00        27
#       Hugo Chavez       0.00      0.00      0.00        11
#        Tony Blair       0.00      0.00      0.00        26
#
#          accuracy                           0.40       258
#         macro avg       0.06      0.14      0.08       258
#      weighted avg       0.16      0.40      0.22       258
#
#
# MDS_GaussianNB:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        17
#      Colin Powell       0.12      0.02      0.04        48
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.40      0.97      0.56       102
# Gerhard Schroeder       0.00      0.00      0.00        27
#       Hugo Chavez       0.00      0.00      0.00        11
#        Tony Blair       0.00      0.00      0.00        26
#
#          accuracy                           0.39       258
#         macro avg       0.07      0.14      0.09       258
#      weighted avg       0.18      0.39      0.23       258
#
#
# MDS_DecisionTreeClassifier:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.16      0.18      0.17        17
#      Colin Powell       0.20      0.27      0.23        48
#   Donald Rumsfeld       0.00      0.00      0.00        27
#     George W Bush       0.38      0.32      0.35       102
# Gerhard Schroeder       0.12      0.07      0.09        27
#       Hugo Chavez       0.00      0.00      0.00        11
#        Tony Blair       0.19      0.23      0.21        26
#
#          accuracy                           0.22       258
#         macro avg       0.15      0.15      0.15       258
#      weighted avg       0.23      0.22      0.22       258
#
#
# LLE_SVC:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        22
#      Colin Powell       0.00      0.00      0.00        47
#   Donald Rumsfeld       0.00      0.00      0.00        21
#     George W Bush       0.38      1.00      0.55        99
# Gerhard Schroeder       0.00      0.00      0.00        28
#       Hugo Chavez       0.00      0.00      0.00        15
#        Tony Blair       0.00      0.00      0.00        26
#
#          accuracy                           0.38       258
#         macro avg       0.05      0.14      0.08       258
#      weighted avg       0.15      0.38      0.21       258
#
#
# LLE_GaussianNB:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        22
#      Colin Powell       0.12      0.06      0.08        47
#   Donald Rumsfeld       0.00      0.00      0.00        21
#     George W Bush       0.38      0.90      0.54        99
# Gerhard Schroeder       0.00      0.00      0.00        28
#       Hugo Chavez       0.00      0.00      0.00        15
#        Tony Blair       0.00      0.00      0.00        26
#
#          accuracy                           0.36       258
#         macro avg       0.07      0.14      0.09       258
#      weighted avg       0.17      0.36      0.22       258
#
#
# LLE_DecisionTreeClassifier:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.07      0.05      0.06        22
#      Colin Powell       0.25      0.26      0.25        47
#   Donald Rumsfeld       0.15      0.19      0.17        21
#     George W Bush       0.34      0.33      0.34        99
# Gerhard Schroeder       0.06      0.07      0.07        28
#       Hugo Chavez       0.00      0.00      0.00        15
#        Tony Blair       0.14      0.12      0.12        26
#
#          accuracy                           0.21       258
#         macro avg       0.14      0.14      0.14       258
#      weighted avg       0.21      0.21      0.21       258
#
#
# ISOMAP_SVC:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        14
#      Colin Powell       0.30      0.07      0.12        41
#   Donald Rumsfeld       0.00      0.00      0.00        33
#     George W Bush       0.40      0.96      0.56       102
# Gerhard Schroeder       0.00      0.00      0.00        20
#       Hugo Chavez       0.00      0.00      0.00        14
#        Tony Blair       0.00      0.00      0.00        34
#
#          accuracy                           0.39       258
#         macro avg       0.10      0.15      0.10       258
#      weighted avg       0.20      0.39      0.24       258
#
#
# ISOMAP_GaussianNB:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.00      0.00      0.00        14
#      Colin Powell       0.42      0.20      0.27        41
#   Donald Rumsfeld       0.00      0.00      0.00        33
#     George W Bush       0.42      0.98      0.59       102
# Gerhard Schroeder       0.00      0.00      0.00        20
#       Hugo Chavez       0.00      0.00      0.00        14
#        Tony Blair       0.00      0.00      0.00        34
#
#          accuracy                           0.42       258
#         macro avg       0.12      0.17      0.12       258
#      weighted avg       0.23      0.42      0.27       258
#
#
# ISOMAP_DecisionTreeClassifier:
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.05      0.07      0.06        14
#      Colin Powell       0.12      0.15      0.13        41
#   Donald Rumsfeld       0.17      0.09      0.12        33
#     George W Bush       0.41      0.42      0.42       102
# Gerhard Schroeder       0.00      0.00      0.00        20
#       Hugo Chavez       0.00      0.00      0.00        14
#        Tony Blair       0.06      0.03      0.04        34
#
#          accuracy                           0.21       258
#         macro avg       0.12      0.11      0.11       258
#      weighted avg       0.21      0.21      0.21       258
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\pym66\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
